# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student_career_data.csv")

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CGPA              1000 non-null   float64
#  1   Logical_Score     1000 non-null   int64
#  2   Coding_Score      1000 non-null   int64
#  3   Speaking_Score    1000 non-null   int64
#  4   Creativity_Score  1000 non-null   int64
#  5   Career_Role       1000 non-null   object
# dtypes: float64(1), int64(4), object(1)
# memory usage: 47.0+ KB
